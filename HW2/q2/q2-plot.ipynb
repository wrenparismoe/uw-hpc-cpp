# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("HW2/q2/performance.csv", sep=',', header=0, names=['blocksize', 'Elapsed Time', 'FLOPs'], dtype=np.float64)

# %%
plt.figure(figsize=(10,5))
plt.title("Level 1 BLAS Performance with Loop Unrolling")
sns.scatterplot(
	x="blocksize",
	y="FLOPs",
	data=data,
	label="FLOPs",
)
plt.xlabel("blocksize", fontsize=12)
plt.ylabel("", fontsize=12)
# Out:
# Text(0, 0.5, '')
